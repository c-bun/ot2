# %%
from opentrons.simulate import simulate, format_runlog
from collections import Counter

log, _bundle = simulate(open("../ot2/pick_colonies_384.py"))
print(
    "The number of tip boxes used: ",
    Counter(format_runlog(log).split())['Picking']/96)
print(format_runlog(log))
# Out:
#     Loaded labware:
#     - 12-well reservoir: NEST 12 Well Reservoir 15 mL on 5
#     - 1 384-well plates: [Grenier BIO-ONE 384 Well Plate 138 µL on 4]
#     - 3 petri dishes: [Celltreat 1 Well Plate 48000 µL on 1, Celltreat 1 Well Plate 48000 µL on 2, Celltreat 1 Well Plate 48000 µL on 3]
#     - 6 tipracks: [Opentrons 96 Tip Rack 20 µL on 6, Opentrons 96 Tip Rack 20 µL on 7, Opentrons 96 Tip Rack 20 µL on 8, Opentrons 96 Tip Rack 20 µL on 9, Opentrons 96 Tip Rack 20 µL on 10, Opentrons 96 Tip Rack 20 µL on 11]
#
# Picking colony 1 of 384 from 1 at x=0.19987840818259264 and y=0.5735789429588336
# Picking colony 2 of 384 from 1 at x=-0.26035719154885373 and y=0.8172127710636772
# Picking colony 3 of 384 from 1 at x=0.8745693397260743 and y=0.009740655059052722
# Picking colony 4 of 384 from 1 at x=0.5540911472429205 and y=-0.1608030246143378
# Picking colony 5 of 384 from 1 at x=0.3613223096590686 and y=0.39607429676816186
# ...

# %%
# %%bash
# opentrons_simulate -e ../ot2/pick_colonies_384.py
# Out:
# /Users/rathbunc/.opentrons/robot_settings.json not found. Loading defaults
# /Users/rathbunc/.opentrons/deck_calibration.json not found. Loading defaults
# Picking colony 1 of 96 from 1 at x=0.2456610071087575 and y=0.2324915836120526
# Picking colony 2 of 96 from 1 at x=0.07698827422288707 and y=-0.7316022790314
# Picking colony 3 of 96 from 1 at x=-0.735050454099089 and y=0.15244046866331828
# Picking colony 4 of 96 from 1 at x=-0.014576923629442568 and y=-0.04942756033783787
# Picking colony 5 of 96 from 1 at x=0.06975944281349263 and y=-0.501890383961119
# Picking colony 6 of 96 from 1 at x=-0.6820390237635298 and y=0.2498939999052557
# Picking colony 7 of 96 from 1 at x=-0.2290322554414778 and y=0.2812183492330213
# Picking colony 8 of 96 from 1 at x=0.17096308254501486 and y=0.8311347040982396
# Picking colony 9 of 96 from 1 at x=-0.00011926081065367657 and y=0.30210124878486505
# Picking colony 10 of 96 from 1 at x=0.009519181068538917 and y=0.8241737375809585
# ...

# %%
191 // 96
# Out:
# 1
