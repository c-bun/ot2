# %%
from opentrons.simulate import simulate, format_runlog
from collections import Counter

log, _bundle = simulate(open("../ot2/test_mutants.py"))
formatted_log = format_runlog(log)
# count the number of times the word 'Picking' appears in the log
print("Columns of tips needed:",Counter(formatted_log.split()).get("Picking"))
#print("Tips used in protocol:",Counter(log_lines)['Picking'])
print(format_runlog(log))
# Out:
# /Users/rathbunc/.opentrons/robot_settings.json not found. Loading defaults
# /Users/rathbunc/.opentrons/deck_calibration.json not found. Loading defaults
# Columns of tips needed: 11
# Picking up tip from A1 of Opentrons 96 Tip Rack 20 µL on 11
# Distributing 10.0 from A1 of Labcon 96 Well Plate 2200 µL on 10 to A1 of Grenier BIO-ONE 384 Well Plate 138 µL on 8
# 	Transferring 10.0 from A1 of Labcon 96 Well Plate 2200 µL on 10 to A1 of Grenier BIO-ONE 384 Well Plate 138 µL on 8
# 		Aspirating 20.0 uL from A1 of Labcon 96 Well Plate 2200 µL on 10 at 7.6 uL/sec
# 		Dispensing 10.0 uL into A1 of Grenier BIO-ONE 384 Well Plate 138 µL on 8 at 7.6 uL/sec
# 		Dispensing 10.0 uL into A2 of Grenier BIO-ONE 384 Well Plate 138 µL on 8 at 7.6 uL/sec
# 		Aspirating 20.0 uL from A1 of Labcon 96 Well Plate 2200 µL on 10 at 7.6 uL/sec
# 		Dispensing 10.0 uL into A3 of Grenier BIO-ONE 384 Well Plate 138 µL on 8 at 7.6 uL/sec
# ...

# %%
# %%bash
# opentrons_simulate -e ../ot2/test_mutants.py
# Out:
# /Users/rathbunc/.opentrons/robot_settings.json not found. Loading defaults
# /Users/rathbunc/.opentrons/deck_calibration.json not found. Loading defaults
# Picking up tip from A1 of Opentrons 96 Tip Rack 20 µL on 11
# Distributing 10.0 from A1 of Labcon 96 Well Plate 2200 µL on 10 to A1 of Grenier BIO-ONE 384 Well Plate 138 µL on 8
# 	Transferring 10.0 from A1 of Labcon 96 Well Plate 2200 µL on 10 to A1 of Grenier BIO-ONE 384 Well Plate 138 µL on 8
# 		Aspirating 20.0 uL from A1 of Labcon 96 Well Plate 2200 µL on 10 at 7.6 uL/sec
# 		Dispensing 10.0 uL into A1 of Grenier BIO-ONE 384 Well Plate 138 µL on 8 at 7.6 uL/sec
# 		Dispensing 10.0 uL into A2 of Grenier BIO-ONE 384 Well Plate 138 µL on 8 at 7.6 uL/sec
# 		Aspirating 20.0 uL from A1 of Labcon 96 Well Plate 2200 µL on 10 at 7.6 uL/sec
# 		Dispensing 10.0 uL into A3 of Grenier BIO-ONE 384 Well Plate 138 µL on 8 at 7.6 uL/sec
# 		Dispensing 10.0 uL into A4 of Grenier BIO-ONE 384 Well Plate 138 µL on 8 at 7.6 uL/sec
# ...
